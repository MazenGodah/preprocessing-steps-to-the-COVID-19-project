# %%
import pandas as pd
import numpy as np
import os

for root, dirs, files in os.walk('/kaggle/input'):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /kaggle/input/corona-virus-report/covid_19_clean_complete.csv
# /kaggle/input/corona-virus-report/country_wise_latest.csv
# /kaggle/input/corona-virus-report/day_wise.csv
# /kaggle/input/corona-virus-report/usa_county_wise.csv
# /kaggle/input/corona-virus-report/worldometer_data.csv
# /kaggle/input/corona-virus-report/full_grouped.csv

# %%
np.seterr(invalid='ignore')
df1 = pd.read_csv('/kaggle/input/corona-virus-report/country_wise_latest.csv')

print(df1.info())
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
print("Number of duplicate rows in df1:", df1.duplicated().sum())
print("\nNumber of missing values in each column of df1:\n", df1.isnull().sum())
# Out:
# Number of duplicate rows in df1: 0
#
# Number of missing values in each column of df1:
#  Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
#clean
path2 = '/kaggle/input/corona-virus-report/covid_19_clean_complete.csv'
df2 = pd.read_csv(path2)
df2
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
print("Dataset Information:\n")
print(df2.info())

print("\nDataset Summary Statistics:\n")
print(df2.describe())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB
# None
#
# Dataset Summary Statistics:
#
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# ...

# %%
df2['Date'] = pd.to_datetime(df2['Date'])
print("Dataset Information:\n")
print(df2.info())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB
# None

# %%
print("Number of duplicate rows:", df2.duplicated().sum())
print("\nNumber of missing values in each column:\n", df2.isnull().sum())
# Out:
# Number of duplicate rows: 0
#
# Number of missing values in each column:
#  Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
df2.drop(['Province/State'], axis=1, inplace=True)

# %%
path3 = '/kaggle/input/corona-virus-report/day_wise.csv'
df3 = pd.read_csv(path3) # Read the file
df3
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
print(df3.info())
df3.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB
# None
# ...

# %%
df3['Date'] = pd.to_datetime(df3['Date'])
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    datetime64[ns]
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 17.8 KB

# %%
df3.isnull().sum()
# Out:
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# No. of countries          0
# dtype: int64

# %%
path4 = '/kaggle/input/corona-virus-report/full_grouped.csv'
df4 = pd.read_csv(path4) # Read File
df4
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
print(df4.info())
df4.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            35156 non-null  object
#  1   Country/Region  35156 non-null  object
#  2   Confirmed       35156 non-null  int64
#  3   Deaths          35156 non-null  int64
#  4   Recovered       35156 non-null  int64
#  5   Active          35156 non-null  int64
#  6   New cases       35156 non-null  int64
#  7   New deaths      35156 non-null  int64
#  8   New recovered   35156 non-null  int64
#  9   WHO Region      35156 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 2.7+ MB
# None
#           Confirmed         Deaths     Recovered        Active    New cases  \
# count  3.515600e+04   35156.000000  3.515600e+04  3.515600e+04  35156.00000
# mean   2.356663e+04    1234.068239  1.104813e+04  1.128443e+04    469.36375
# ...

# %%
df4['Date'] = pd.to_datetime(df4['Date'])
print("Dataset Information:\n")
print(df4.info())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            35156 non-null  datetime64[ns]
#  1   Country/Region  35156 non-null  object
#  2   Confirmed       35156 non-null  int64
#  3   Deaths          35156 non-null  int64
#  4   Recovered       35156 non-null  int64
#  5   Active          35156 non-null  int64
#  6   New cases       35156 non-null  int64
#  7   New deaths      35156 non-null  int64
#  8   New recovered   35156 non-null  int64
#  9   WHO Region      35156 non-null  object
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 2.7+ MB
# None

# %%
print("Number of missing values in each column of df4:\n", df4.isnull().sum())
print("\nNumber of duplicate rows in df4:", df4.duplicated().sum())
# Out:
# Number of missing values in each column of df4:
#  Date              0
# Country/Region    0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# New cases         0
# New deaths        0
# New recovered     0
# WHO Region        0
# dtype: int64
#
# Number of duplicate rows in df4: 0

# %%
path5 = '/kaggle/input/corona-virus-report/usa_county_wise.csv'
df5 = pd.read_csv(path5)
df5
# Out:
#              UID iso2 iso3  code3     FIPS          Admin2  \
# 0             16   AS  ASM     16     60.0             NaN
# 1            316   GU  GUM    316     66.0             NaN
# 2            580   MP  MNP    580     69.0             NaN
# 3       63072001   PR  PRI    630  72001.0        Adjuntas
# 4       63072003   PR  PRI    630  72003.0          Aguada
# ...          ...  ...  ...    ...      ...             ...
# 627915  84070016   US  USA    840      NaN    Central Utah
# 627916  84070017   US  USA    840      NaN  Southeast Utah
# 627917  84070018   US  USA    840      NaN  Southwest Utah
# 627918  84070019   US  USA    840      NaN       TriCounty
# 627919  84070020   US  USA    840      NaN    Weber-Morgan
#
#                   Province_State Country_Region        Lat       Long_  \
# 0                 American Samoa             US -14.271000 -170.132000
# 1                           Guam             US  13.444300  144.793700
# ...

# %%
print("Dataset Information:\n")
print(df5.info())

print("\nDataset Summary Statistics:\n")
print(df5.describe())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627920 entries, 0 to 627919
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UID             627920 non-null  int64
#  1   iso2            627920 non-null  object
#  2   iso3            627920 non-null  object
#  3   code3           627920 non-null  int64
#  4   FIPS            626040 non-null  float64
#  5   Admin2          626792 non-null  object
#  6   Province_State  627920 non-null  object
#  7   Country_Region  627920 non-null  object
#  8   Lat             627920 non-null  float64
#  9   Long_           627920 non-null  float64
#  10  Combined_Key    627920 non-null  object
#  11  Date            627920 non-null  object
#  12  Confirmed       627920 non-null  int64
#  13  Deaths          627920 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 67.1+ MB
# None
#
# Dataset Summary Statistics:
#
# ...

# %%
df5['Date'] = pd.to_datetime(df5['Date'], format='%m/%d/%y')
print("Dataset Information:\n")
print(df5.info())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627920 entries, 0 to 627919
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   UID             627920 non-null  int64
#  1   iso2            627920 non-null  object
#  2   iso3            627920 non-null  object
#  3   code3           627920 non-null  int64
#  4   FIPS            626040 non-null  float64
#  5   Admin2          626792 non-null  object
#  6   Province_State  627920 non-null  object
#  7   Country_Region  627920 non-null  object
#  8   Lat             627920 non-null  float64
#  9   Long_           627920 non-null  float64
#  10  Combined_Key    627920 non-null  object
#  11  Date            627920 non-null  datetime64[ns]
#  12  Confirmed       627920 non-null  int64
#  13  Deaths          627920 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(6)
# memory usage: 67.1+ MB
# None

# %%
print("Number of duplicate rows in df5:", df5.duplicated().sum())
print("\n\nNumber of missing values in each column of df5:\n", df5.isnull().sum())
# Out:
# Number of duplicate rows in df5: 0
#
#
# Number of missing values in each column of df5:
#  UID                  0
# iso2                 0
# iso3                 0
# code3                0
# FIPS              1880
# Admin2            1128
# Province_State       0
# Country_Region       0
# Lat                  0
# Long_                0
# Combined_Key         0
# Date                 0
# Confirmed            0
# Deaths               0
# dtype: int64

# %%
df5.dropna(subset=['FIPS', 'Admin2'], inplace=True)
print("Number of missing values in each column after dropping rows:\n", df5.isnull().sum())
# Out:
# Number of missing values in each column after dropping rows:
#  UID               0
# iso2              0
# iso3              0
# code3             0
# FIPS              0
# Admin2            0
# Province_State    0
# Country_Region    0
# Lat               0
# Long_             0
# Combined_Key      0
# Date              0
# Confirmed         0
# Deaths            0
# dtype: int64

# %%
path6 = '/kaggle/input/corona-virus-report/worldometer_data.csv'
df6 = pd.read_csv(path6)
df6
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
print("Dataset Information:\n")
print(df6.info())

print("\nDataset Summary Statistics:\n")
print(df6.describe())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
# ...

# %%
print("Number of duplicate rows in df6:", df6.duplicated().sum())
print("\nNumber of missing values in each column of df6:\n", df6.isnull().sum())
# Out:
# Number of duplicate rows in df6: 0
#
# Number of missing values in each column of df6:
#  Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
df6.fillna({'NewCases': 0, 'NewDeaths': 0, 'NewRecovered': 0}, inplace=True)
print("Number of missing values in each column after filling:\n", df6.isnull().sum())
# Out:
# Number of missing values in each column after filling:
#  Country/Region       0
# Continent            1
# Population           1
# TotalCases           0
# NewCases             0
# TotalDeaths         21
# NewDeaths            0
# TotalRecovered       4
# NewRecovered         0
# ActiveCases          4
# Serious,Critical    87
# Tot Cases/1M pop     1
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
df6.drop(['Serious,Critical'], axis=1, inplace=True)
df6['WHO Region'] = df6['WHO Region'].fillna('Unknown')
print("Number of missing values in each column after modification:\n", df6.isnull().sum())
# Out:
# Number of missing values in each column after modification:
#  Country/Region       0
# Continent            1
# Population           1
# TotalCases           0
# NewCases             0
# TotalDeaths         21
# NewDeaths            0
# TotalRecovered       4
# NewRecovered         0
# ActiveCases          4
# Tot Cases/1M pop     1
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region           0
# dtype: int64

# %%
df6.dropna(inplace=True)
print("Number of missing values in each column after dropping rows:\n", df6.isnull().sum())
# Out:
# Number of missing values in each column after dropping rows:
#  Country/Region      0
# Continent           0
# Population          0
# TotalCases          0
# NewCases            0
# TotalDeaths         0
# NewDeaths           0
# TotalRecovered      0
# NewRecovered        0
# ActiveCases         0
# Tot Cases/1M pop    0
# Deaths/1M pop       0
# TotalTests          0
# Tests/1M pop        0
# WHO Region          0
# dtype: int64
